# %%
valor_1 = 4
valor_2 = 8
valor_total = valor_1 + valor_2
valor_media = valor_total / 2
print(f'valor_total = {valor_total}')
print(f'valor_media = {valor_media}')
print(f'valor_1 = {valor_1}')
print(f'valor_2 = {valor_2}')
